# %%
sentences = [
 "I love this product",
 "This movie made me smile",
 "Service was friendly and quick",
 "Today felt bright and happy",
 "This is the best day",
 "Absolutely fantastic experience",
 "I enjoyed every single moment",
 "Great job, well done",
 "The food tasted delicious",
 "Totally recommend to everyone",
 "Very satisfied with results",
 "This worked better than expected",
 "Amazing quality and value",
 "Such a pleasant surprise",
 "I feel positive about this",
 "I hate this product",
 "This movie bored me",
 "Service was rude and slow",
 "Today was cold and lonely",
 "This is the worst day",
 "Terrible experience overall",
 "I regret buying this",
 "Very disappointed with results",
 "The food tasted awful",
 "Do not recommend this",
 "It broke after one use",
 "Not worth the money",
 "Utterly frustrating and annoying",
 "I feel negative about this",
 "Such a waste of time",
]

# %%
sentences.index("Very disappointed with results")  #14 28
# Out:
# 22

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# 2026-04-10 06:55:37.450822: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775804137.741707      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775804137.823914      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775804138.468442      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775804138.468523      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775804138.468527      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775804138.468530      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# text -----> tokens
# tokens------> vocab
# vocab-----> number
# numbers------> embaddings

# %%
tokenizer= Tokenizer()

# %%
tokenizer.fit_on_texts(sentences)

# %%
word_index=tokenizer.word_index

# %%
word_index
# Out:
# {'this': 1,
#  'i': 2,
#  'and': 3,
#  'the': 4,
#  'was': 5,
#  'product': 6,
#  'movie': 7,
#  'me': 8,
#  'service': 9,
#  'today': 10,
#  'is': 11,
#  'day': 12,
#  'experience': 13,
#  'food': 14,
#  'tasted': 15,
#  'recommend': 16,
#  'very': 17,
#  'with': 18,
#  'results': 19,
#  'such': 20,
#  'a': 21,
#  'feel': 22,
#  'about': 23,
#  'not': 24,
#  'love': 25,
#  'made': 26,
#  'smile': 27,
#  'friendly': 28,
#  'quick': 29,
#  'felt': 30,
#  'bright': 31,
#  'happy': 32,
#  'best': 33,
#  'absolutely': 34,
#  'fantastic': 35,
#  'enjoyed': 36,
#  'every': 37,
#  'single': 38,
#  'moment': 39,
#  'great': 40,
#  'job': 41,
#  'well': 42,
#  'done': 43,
#  'delicious': 44,
#  'totally': 45,
#  'to': 46,
#  'everyone': 47,
#  'satisfied': 48,
#  'worked': 49,
#  'better': 50,
#  'than': 51,
#  'expected': 52,
#  'amazing': 53,
#  'quality': 54,
#  'value': 55,
#  'pleasant': 56,
#  'surprise': 57,
#  'positive': 58,
#  'hate': 59,
#  'bored': 60,
#  'rude': 61,
#  'slow': 62,
#  'cold': 63,
#  'lonely': 64,
#  'worst': 65,
#  'terrible': 66,
#  'overall': 67,
#  'regret': 68,
#  'buying': 69,
#  'disappointed': 70,
#  'awful': 71,
#  'do': 72,
#  'it': 73,
#  'broke': 74,
#  'after': 75,
#  'one': 76,
#  'use': 77,
#  'worth': 78,
#  'money': 79,
#  'utterly': 80,
#  'frustrating': 81,
#  'annoying': 82,
#  'negative': 83,
#  'waste': 84,
#  'of': 85,
#  'time': 86}

# %%
seq=tokenizer.texts_to_sequences(sentences)
seq
# Out:
# [[2, 25, 1, 6],
#  [1, 7, 26, 8, 27],
#  [9, 5, 28, 3, 29],
#  [10, 30, 31, 3, 32],
#  [1, 11, 4, 33, 12],
#  [34, 35, 13],
#  [2, 36, 37, 38, 39],
#  [40, 41, 42, 43],
#  [4, 14, 15, 44],
#  [45, 16, 46, 47],
#  [17, 48, 18, 19],
#  [1, 49, 50, 51, 52],
#  [53, 54, 3, 55],
#  [20, 21, 56, 57],
#  [2, 22, 58, 23, 1],
#  [2, 59, 1, 6],
#  [1, 7, 60, 8],
#  [9, 5, 61, 3, 62],
#  [10, 5, 63, 3, 64],
#  [1, 11, 4, 65, 12],
#  [66, 13, 67],
#  [2, 68, 69, 1],
#  [17, 70, 18, 19],
#  [4, 14, 15, 71],
#  [72, 24, 16, 1],
#  [73, 74, 75, 76, 77],
#  [24, 78, 4, 79],
#  [80, 81, 3, 82],
#  [2, 22, 83, 23, 1],
#  [20, 21, 84, 85, 86]]

# %%
len(seq)
# Out:
# 30

# %%
max_len= 0
for i in seq:
    if len(i)> max_len:
        max_len= len(i)

# %%
max_len
# Out:
# 5

# %%
pad_seq= pad_sequences(seq, maxlen=max_len, padding= 'pre')

# %%
pad_seq
# Out:
# array([[ 0,  2, 25,  1,  6],
#        [ 1,  7, 26,  8, 27],
#        [ 9,  5, 28,  3, 29],
#        [10, 30, 31,  3, 32],
#        [ 1, 11,  4, 33, 12],
#        [ 0,  0, 34, 35, 13],
#        [ 2, 36, 37, 38, 39],
#        [ 0, 40, 41, 42, 43],
#        [ 0,  4, 14, 15, 44],
#        [ 0, 45, 16, 46, 47],
#        [ 0, 17, 48, 18, 19],
#        [ 1, 49, 50, 51, 52],
#        [ 0, 53, 54,  3, 55],
#        [ 0, 20, 21, 56, 57],
#        [ 2, 22, 58, 23,  1],
#        [ 0,  2, 59,  1,  6],
#        [ 0,  1,  7, 60,  8],
#        [ 9,  5, 61,  3, 62],
#        [10,  5, 63,  3, 64],
#        [ 1, 11,  4, 65, 12],
#        [ 0,  0, 66, 13, 67],
#        [ 0,  2, 68, 69,  1],
#        [ 0, 17, 70, 18, 19],
#        [ 0,  4, 14, 15, 71],
#        [ 0, 72, 24, 16,  1],
#        [73, 74, 75, 76, 77],
#        [ 0, 24, 78,  4, 79],
#        [ 0, 80, 81,  3, 82],
#        [ 2, 22, 83, 23,  1],
#        [20, 21, 84, 85, 86]], dtype=int32)

# %%
vocab_size= len(word_index)+1
vocab_size
# Out:
# 87

# %%
emd_dim= 8

# %%
emd_layer= Embedding(
    input_dim= vocab_size,
    output_dim= emd_dim,
    input_length= max_len
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
embd=emd_layer(pad_seq)

# %%
embd[0]
# Out:
# <tf.Tensor: shape=(5, 8), dtype=float32, numpy=
# array([[-0.01264704, -0.00869726,  0.04600686,  0.0428046 , -0.01309337,
#          0.02791421, -0.00502876,  0.02599775],
#        [ 0.02113051, -0.01047878,  0.04835541,  0.04099866, -0.01417992,
#          0.04098499,  0.00663383,  0.01825221],
#        [ 0.00416588,  0.04125572, -0.01021122,  0.0424029 ,  0.01579148,
#         -0.01106769,  0.00616733, -0.02816987],
#        [ 0.01909757, -0.02014025, -0.02023467, -0.00385309, -0.04523503,
#          0.0114008 , -0.02161633, -0.04203904],
#        [ 0.04518029, -0.01194104, -0.01226829, -0.03302211,  0.03808529,
#          0.01672463,  0.01738143,  0.04214266]], dtype=float32)>

# %%
sentences[0]
# Out:
# 'I love this product'

# %%
embd[0][1]
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([ 0.02113051, -0.01047878,  0.04835541,  0.04099866, -0.01417992,
#         0.04098499,  0.00663383,  0.01825221], dtype=float32)>

# %%
sentences[6]
# Out:
# 'I enjoyed every single moment'

# %%
embd[6][0]
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([ 0.02113051, -0.01047878,  0.04835541,  0.04099866, -0.01417992,
#         0.04098499,  0.00663383,  0.01825221], dtype=float32)>

# %%
embd[14]
# Out:
# <tf.Tensor: shape=(5, 8), dtype=float32, numpy=
# array([[ 0.02113051, -0.01047878,  0.04835541,  0.04099866, -0.01417992,
#          0.04098499,  0.00663383,  0.01825221],
#        [ 0.00375961,  0.03960533,  0.03288392, -0.02110555,  0.03125367,
#          0.01951103,  0.01030078,  0.02614825],
#        [ 0.01808197,  0.00799624, -0.03020096,  0.04297957, -0.02882205,
#         -0.02923334,  0.03468721, -0.04718473],
#        [-0.0060964 ,  0.02943384,  0.02979407,  0.00853137, -0.02260561,
#          0.01009916, -0.00012367,  0.04429278],
#        [ 0.01909757, -0.02014025, -0.02023467, -0.00385309, -0.04523503,
#          0.0114008 , -0.02161633, -0.04203904]], dtype=float32)>

# %%
embd[28]
# Out:
# <tf.Tensor: shape=(5, 8), dtype=float32, numpy=
# array([[ 0.02113051, -0.01047878,  0.04835541,  0.04099866, -0.01417992,
#          0.04098499,  0.00663383,  0.01825221],
#        [ 0.00375961,  0.03960533,  0.03288392, -0.02110555,  0.03125367,
#          0.01951103,  0.01030078,  0.02614825],
#        [ 0.01343966, -0.04770055,  0.02211961, -0.01085426,  0.01440677,
#         -0.0125749 ,  0.00445728, -0.0177259 ],
#        [-0.0060964 ,  0.02943384,  0.02979407,  0.00853137, -0.02260561,
#          0.01009916, -0.00012367,  0.04429278],
#        [ 0.01909757, -0.02014025, -0.02023467, -0.00385309, -0.04523503,
#          0.0114008 , -0.02161633, -0.04203904]], dtype=float32)>

# %%
positive=embd[14][2]
same= embd[22][2]

# %%
negitive=embd[28][2]
same1= embd[28][0]

# %%
import matplotlib.pyplot as plt

# %%
negitive
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([ 0.01343966, -0.04770055,  0.02211961, -0.01085426,  0.01440677,
#        -0.0125749 ,  0.00445728, -0.0177259 ], dtype=float32)>

# %%
for i in range(len(positive)):
    x= positive[i]
    y= positive[i+1]
    a1= same[i]
    a2= same[i+1]
    print(x,y)
    x1= negitive[i]
    y1= negitive[i+1]
    b1= same1[i]
    b2= same1[i+1]
    print(x1,y1)
    plt.scatter(x,y)
    plt.scatter(x1,y1, color= 'red')

    plt.scatter(a1,a2, marker='o', color= 'black')
    plt.scatter(b1,b2, marker= "+")
    
    plt.show()
    if i==6:
        break
# Out:
# tf.Tensor(0.018081974, shape=(), dtype=float32) tf.Tensor(0.007996239, shape=(), dtype=float32)
# tf.Tensor(0.013439659, shape=(), dtype=float32) tf.Tensor(-0.04770055, shape=(), dtype=float32)
# tf.Tensor(0.007996239, shape=(), dtype=float32) tf.Tensor(-0.030200958, shape=(), dtype=float32)
# tf.Tensor(-0.04770055, shape=(), dtype=float32) tf.Tensor(0.022119608, shape=(), dtype=float32)
# tf.Tensor(-0.030200958, shape=(), dtype=float32) tf.Tensor(0.042979572, shape=(), dtype=float32)
# tf.Tensor(0.022119608, shape=(), dtype=float32) tf.Tensor(-0.010854255, shape=(), dtype=float32)
# tf.Tensor(0.042979572, shape=(), dtype=float32) tf.Tensor(-0.028822053, shape=(), dtype=float32)
# tf.Tensor(-0.010854255, shape=(), dtype=float32) tf.Tensor(0.014406774, shape=(), dtype=float32)
# tf.Tensor(-0.028822053, shape=(), dtype=float32) tf.Tensor(-0.029233336, shape=(), dtype=float32)
# tf.Tensor(0.014406774, shape=(), dtype=float32) tf.Tensor(-0.0125749, shape=(), dtype=float32)
# tf.Tensor(-0.029233336, shape=(), dtype=float32) tf.Tensor(0.03468721, shape=(), dtype=float32)
# tf.Tensor(-0.0125749, shape=(), dtype=float32) tf.Tensor(0.0044572838, shape=(), dtype=float32)
# tf.Tensor(0.03468721, shape=(), dtype=float32) tf.Tensor(-0.04718473, shape=(), dtype=float32)
# tf.Tensor(0.0044572838, shape=(), dtype=float32) tf.Tensor(-0.017725896, shape=(), dtype=float32)

# %%
len(positive)
# Out:
# 8

# %%
# for i in range(len(positive)):
#     x= positive[i]
#     y= positive[i+1]
#     print(x,y)
#     x1= negitive[i]
#     y1= negitive[i+1]
#     print(x1,y1)
#     plt.scatter(x,y)
#     plt.scatter(x1,y1)
#     plt.show()
#     if i==6:
#         break

# %%
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([-0.03760713, -0.03373327,  0.02124104,  0.03778037,  0.01135569,
#        -0.01352702, -0.01935481, -0.03596275], dtype=float32)>
